# %% [markdown]
# ### Convolutional Neural Network - 과적합 방지 #2 (컬러 이미지).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings  
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets.cifar10 import load_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator                 # 데이터 증강을 위한 클래스.
warnings.filterwarnings('ignore')                  # Turn the warnings off.
# %matplotlib inline

# %% [markdown]
# #### 1. 데이터 불러오기:

# %% [markdown]
# 자세한 설명은 [이곳](https://www.cs.toronto.edu/~kriz/cifar.html)을 참고한다.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# 데이터 가져오기.
(X_train, y_train), (X_test, y_test) = load_data()
n_train_size = X_train.shape[0]
n_test_size = X_test.shape[0]
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce so we will re-download the data.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 77s 0us/step

# %%
# Shape 확인.
print("-"*50)
print("Training data X shape: {}".format(X_train.shape))
print("Training data y shape: {}".format(y_train.shape))
print("-"*50)
print("Test data X shape: {}".format(X_test.shape))
print("Test data y shape: {}".format(y_test.shape))
print("-"*50)
# Out:
# --------------------------------------------------
# Training data X shape: (50000, 32, 32, 3)
# Training data y shape: (50000, 1)
# --------------------------------------------------
# Test data X shape: (10000, 32, 32, 3)
# Test data y shape: (10000, 1)
# --------------------------------------------------

# %% [markdown]
# #### 2. 데이터 시각화:

# %%
name_dict = {0:"Airplane", 1:"Automobile", 2:"Bird", 3:"Cat", 4:"Deer", 5:"Dog", 6:"Frog", 7:"Horse", 8:"Ship", 9:"Truck"}

# %%
# 이미지 데이터 시각화 (5개).
for i_image in [ random.randint(0,n_train_size-1) for _ in range(5)]:
    print("Y 레이블 :",name_dict[y_train[i_image][0]])
    plt.figure(figsize=(2,2))
    plt.imshow(X_train[i_image])
    plt.axis("off")
    plt.show()
# Out:
# Y 레이블 : Airplane
# Y 레이블 : Frog
# Y 레이블 : Horse
# Y 레이블 : Airplane
# Y 레이블 : Airplane

# %% [markdown]
# #### 3. 데이터 준비:

# %% [markdown]
# #### 3.1. 데이터 전처리:

# %%
# Scaling.
X_train = X_train/255                   
X_test = X_test/255

# %%
# 4 차원 배열로 reshaping 해준다.
X_train = X_train.reshape(-1,32,32,3)
X_test = X_test.reshape(-1,32,32,3)

# %%
# One-hot-encoding.
y = np.concatenate([y_train,y_test],axis=0)
y = to_categorical(y,10)
y_train = y[:n_train_size,:]
y_test = y[n_train_size:,:]

# %% [markdown]
# #### 3.2. 데이터 증강:

# %% [markdown]
# 데이터 증강 준비.
# - rotation_range : 회전 최대 각도.
# - zoom_range : 확대 최대 비율.
# - shear_range : 기울기 최대 각도.
# - width_shift_range : 좌우 이동 최대 값.
# - height_shift_range : 상하 이동 최대 값.
# - horizontal_flip : 가로 방향으로 뒤집기 가능 여부.
# - vertical_filp : 세로 방향 뒤집기 가능 여부.

# %%
# 객체 생성.
my_datagen = ImageDataGenerator(
                rotation_range=10,
                zoom_range =0.2,
                shear_range = 1,
                width_shift_range=0.2,
                height_shift_range=0.2,
                horizontal_flip=True,
                vertical_flip=False)

# %%
# 데이터 증강 테스트.
for i in range(5):
    fig, axes = plt.subplots(1, 5)
    X_gen = my_datagen.flow(X_train[:5, :,:,:], batch_size=5, shuffle = False).next()    # 랜덤으로 5개씩 데이터 증강한다. 순서는 유지.
    for j in range(5):
        axes[j].imshow(X_gen[j,:,:,:])
        axes[j].axis('off')
    plt.show()

# %%
# 데이터 증강 (2 배).
X_gen, y_gen = my_datagen.flow(X_train, y_train, batch_size=n_train_size, shuffle = True).next()  
X_train_aug = np.concatenate([X_train, X_gen], axis=0)   # 새롭게 증강된 데이터를 기존 데이터에 이어 붙인다. 
y_train_aug = np.concatenate([y_train, y_gen], axis=0)   # 새롭게 증강된 데이터를 기존 데이터에 이어 붙인다.

# %%
# Shape 확인.
print("Augmented training data X shape: {}".format(X_train_aug.shape))
print("Augmented training data y shape: {}".format(y_train_aug.shape))
# Out:
# Augmented training data X shape: (100000, 32, 32, 3)
# Augmented training data y shape: (100000, 10)

# %%
# 데이터를 다시한번 섞어준다.
n_train_size = X_train_aug.shape[0]
idx = list(range(n_train_size))
random.shuffle(idx)
X_train_aug = X_train_aug[idx,:,:,:]
y_train_aug = y_train_aug[idx,:]

# %% [markdown]
# #### 4. CNN 모델 정의 (BatchNormalization, Regularization):

# %%
# 과적합 방지 방법 적용!
# 1. Dropoput.
# 2. BatchNormalization (배치 정규화).
# 3. L2 정규화 (regularization).
# 4. 데이터 증강 (데이터 전처리와 학습 section 참고).

drop_prob = 0.7
gamma = 0.0001
my_model = Sequential()
# 1st convolution + pooling.
my_model.add(Conv2D(input_shape=(32,32,3),filters=32,kernel_size=(5,5),padding='same',activation="relu", name="Conv-1"))        # 3 channels of color.
my_model.add(MaxPooling2D(pool_size=2, name="Pooling-1"))
my_model.add(BatchNormalization(name="BatchNormazliation"))                                           # 배치 정규화.
# 2nd convolution + pooling.
my_model.add(Conv2D(filters=64,kernel_size=(5,5), padding='same',activation="relu", name="Conv-2"))
my_model.add(MaxPooling2D(pool_size=2, name="Pooling-2"))
# Flattened fully connected layer.
my_model.add(Flatten(name="Flatten"))
my_model.add(Dense(units = 1024, activation="relu", name="Dense-1", kernel_regularizer=l2(gamma), bias_regularizer=l2(gamma)))  # L2 정규화 적용!
# Apply dropout.
my_model.add(Dropout(rate=drop_prob, name="Dropout"))
# Output layer.
my_model.add(Dense(units = 10, activation="softmax", name="Dense-2"))

# %%
# 모델의 summary (내부 구조) 출력.
# Conv-1의 파라미터 수 = n_channels * n_filters1 * n_kernel_elements1 + n_filters1 = 3 * 32 * (5*5) + 32 = 2432
# Conv-2의 파라미터 수 = n_filters1 * n_filters2 * n_kernel_elements2 + n_filters2 = 32 * 64 * (5*5) + 64 = 51264.
# Dense-1의 파라미터 수 = 이전층의 출력 * n_nodes + n_nodes = 4096 * 1024 + 1024 = 4195328.
# Dense-2의 파라미터 수 = 이전층의 출력 * n_output + n_output = 1024 * 10 + 10 = 10250.
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv-1 (Conv2D)             (None, 32, 32, 32)        2432
#
#  Pooling-1 (MaxPooling2D)    (None, 16, 16, 32)        0
#
#  BatchNormazliation (BatchNo  (None, 16, 16, 32)       128
#  rmalization)
#
#  Conv-2 (Conv2D)             (None, 16, 16, 64)        51264
#
#  Pooling-2 (MaxPooling2D)    (None, 8, 8, 64)          0
#
#  Flatten (Flatten)           (None, 4096)              0
#
#  Dense-1 (Dense)             (None, 1024)              4195328
#
#  Dropout (Dropout)           (None, 1024)              0
#
#  Dense-2 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 4,259,402
# Trainable params: 4,259,338
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### 5. Hyperparameter 와 Optimizer 정의:

# %%
# Hyperparameters.
n_epochs = 30
batch_size = 32
learn_rate = 0.0001

# %%
# Optimizer 객체 생성 후 컴파일한다.
my_optimizer=Adam(lr=learn_rate)
my_model.compile(loss = "categorical_crossentropy", optimizer = my_optimizer, metrics=["accuracy"])

# %% [markdown]
# #### 6. 학습 & History 시각화:

# %%
# 증강된 데이터를 사용한 학습.
# verbose = 0 : 출력 없음. verbose = 1 : 출력 함.
my_EarlyStop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)          # 조기 종료 허락!
my_summary = my_model.fit(X_train_aug, y_train_aug, epochs=n_epochs, batch_size = batch_size, validation_split = 0.3, verbose = 1,callbacks=[my_EarlyStop])
# Out:
# Epoch 1/30
# 2188/2188 [==============================] - 103s 47ms/step - loss: 1.8502 - accuracy: 0.3846 - val_loss: 1.5813 - val_accuracy: 0.4752
# Epoch 2/30
# 2188/2188 [==============================] - 101s 46ms/step - loss: 1.5373 - accuracy: 0.4935 - val_loss: 1.3806 - val_accuracy: 0.5538
# Epoch 3/30
# 2188/2188 [==============================] - 106s 48ms/step - loss: 1.3599 - accuracy: 0.5549 - val_loss: 1.2118 - val_accuracy: 0.6087
# Epoch 4/30
# 2188/2188 [==============================] - 110s 50ms/step - loss: 1.2386 - accuracy: 0.5969 - val_loss: 1.1472 - val_accuracy: 0.6246
# Epoch 5/30
# 2188/2188 [==============================] - 111s 51ms/step - loss: 1.1482 - accuracy: 0.6282 - val_loss: 1.1187 - val_accuracy: 0.6343
# Epoch 6/30
# 2188/2188 [==============================] - 109s 50ms/step - loss: 1.0730 - accuracy: 0.6551 - val_loss: 1.0994 - val_accuracy: 0.6467
# Epoch 7/30
# 2188/2188 [==============================] - 112s 51ms/step - loss: 1.0138 - accuracy: 0.6773 - val_loss: 1.0515 - val_accuracy: 0.6614
# Epoch 8/30
# 2188/2188 [==============================] - 112s 51ms/step - loss: 0.9589 - accuracy: 0.6974 - val_loss: 1.0681 - val_accuracy: 0.6546
# Epoch 9/30
# 2188/2188 [==============================] - 112s 51ms/step - loss: 0.9088 - accuracy: 0.7174 - val_loss: 1.0021 - val_accuracy: 0.6820
# Epoch 10/30
# 2188/2188 [==============================] - 111s 51ms/step - loss: 0.8617 - accuracy: 0.7362 - val_loss: 1.2369 - val_accuracy: 0.6222
# Epoch 11/30
# 2188/2188 [==============================] - 112s 51ms/step - loss: 0.8180 - accuracy: 0.7512 - val_loss: 1.2639 - val_accuracy: 0.6175
# Epoch 12/30
# 2188/2188 [==============================] - 110s 50ms/step - loss: 0.7792 - accuracy: 0.7649 - val_loss: 0.9798 - val_accuracy: 0.6986
# Epoch 13/30
# 2188/2188 [==============================] - 115s 53ms/step - loss: 0.7369 - accuracy: 0.7811 - val_loss: 0.9564 - val_accuracy: 0.7051
# Epoch 14/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.7053 - accuracy: 0.7940 - val_loss: 0.9804 - val_accuracy: 0.7064
# Epoch 15/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.6740 - accuracy: 0.8054 - val_loss: 0.9767 - val_accuracy: 0.7077
# Epoch 16/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.6402 - accuracy: 0.8183 - val_loss: 0.9542 - val_accuracy: 0.7166
# Epoch 17/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.6108 - accuracy: 0.8307 - val_loss: 0.9660 - val_accuracy: 0.7193
# Epoch 18/30
# 2188/2188 [==============================] - 113s 51ms/step - loss: 0.5846 - accuracy: 0.8412 - val_loss: 1.0217 - val_accuracy: 0.7111
# Epoch 19/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.5556 - accuracy: 0.8541 - val_loss: 0.9788 - val_accuracy: 0.7207
# Epoch 20/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.5310 - accuracy: 0.8625 - val_loss: 1.0428 - val_accuracy: 0.7146
# Epoch 21/30
# 2188/2188 [==============================] - 114s 52ms/step - loss: 0.5090 - accuracy: 0.8720 - val_loss: 0.9902 - val_accuracy: 0.7246
# Epoch 21: early stopping

# %%
# 학습 history 출력. 
n_skip = 0                 # Skip the first few steps.
plt.plot(my_summary.history['accuracy'][n_skip:], c="b")
plt.plot(my_summary.history['val_accuracy'][n_skip:], c="g")
plt.title('Training History')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# #### 7.  테스팅:

# %%
# 랜덤으로 테스트 이미지를 추출해서 예측해 본다.
for i_image in [ random.randint(0,n_test_size-1) for _ in range(5)]:
    print("정답 :" , name_dict[np.argmax(y_test[i_image])])
    print("예측 :" , name_dict[np.argmax(my_model.predict(X_test[i_image].reshape(1,32,32,3)))])     # 4 차원 배열로 reshaping 해준다!!!
    plt.figure(figsize=(1,1))
    plt.imshow(X_test[i_image])
    plt.axis("off")
    plt.show()
# Out:
# 정답 : Cat
# 1/1 [==============================] - 0s 94ms/step
# 예측 : Cat
# 정답 : Frog
# 1/1 [==============================] - 0s 17ms/step
# 예측 : Frog
# 정답 : Bird
# 1/1 [==============================] - 0s 15ms/step
# 예측 : Bird
# 정답 : Dog
# 1/1 [==============================] - 0s 15ms/step
# 예측 : Dog
# 정답 : Dog
# 1/1 [==============================] - 0s 15ms/step
# 예측 : Dog

# %%
# 최종적으로 정확도 계산.
ACC = my_model.evaluate(X_test, y_test, verbose=0)[1]    
print("Test Accuracy : {}".format(np.round(ACC,3)))
# Out:
# Test Accuracy : 0.77

# %% [markdown]
# **NOTE**: 이전과 비교해서 다소 향상되었다!
